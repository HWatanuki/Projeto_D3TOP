# %% [markdown]
# >Instituto Federal de Educação, Ciência e Tecnologia
# >>Câmpus Campinas<br>
# >>D3TOP – Tópicos em Ciência de Dados<br>
# >>Prof.: Samuel Botter Martins<br>

# %% [markdown]
# ## Preprocessing and data clean step

# %% [markdown]
# ### Environment Config

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# %%capture
# !pip install -U spacy
# !pip install -U gensim
# !pip install -U neattext
# !pip install -U pyspellchecker
# !pip install -U stanza 
# !pip install unidecode

# %%
# Importando bibliotecas e setando parâmetros

import numpy as np
import pandas as pd
from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 500)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# seta o idioma principal do dataset a ser processado e limpo
LANG = 'english' # or 'portuguese'

# %% [markdown]
# #### Useful Functions

# %%
def remove_cols(df, mask_cmds, inverse=True):
  '''
  Remove colunas de um dado dataframe df, a partir de uma máscara booleana mask.

  Parameters:
    df (pd.Dataframe): dataframe no qual sofrera a operacao de remocao de colunas
    mask_cmds (list): array de expressões a serem avaliadas. As expressões deve retornar array de booleanos contendo True nas posições das colunas que se deseja remover
    inverse (bool): (opcional) - indica se a máscara será invertida ou não. Default: True

  Returns:
    df (pd.Dataframe): dataframe sem as colunas indicadas na máscara
  '''
  mask_exp = mask_cmds.pop(0)
  mask = eval(mask_exp)
  if inverse:
    return remove_cols(df[df.columns[~mask]], mask_cmds) if len(mask_cmds) else df[df.columns[~mask]]
  return remove_cols(df[df.columns[mask]], mask_cmds) if len(mask_cmds) else df[df.columns[mask]]

# %%
def missing_values_table(df):
  '''
  Funcao que retorna o calculo de valores ausentes, absoluto e percentual, das colunas de um dado dataframe pandas

  Parameters:
    df (pd.Dataframe): dataframe que será  avaliado

  Returns:
    df (pd.Dataframe): dataframe contendo nas linhas o nome das colunas do dataframe original, e nas colunas
    a quantidade total de valores ausentes e o seu percentual correspondente.
  '''
  # Total missing values
  mis_val = df.isnull().sum()
  
  # Percentage of missing values
  mis_val_percent = 100 * df.isnull().sum() / len(df)
  
  # Make a table with the results
  mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
  
  # Rename the columns
  mis_val_table_ren_columns = mis_val_table.rename(
  columns = {0 : 'Missing Values', 1 : '% of Total Values'})
  
  # Sort the table by percentage of missing descending
  mis_val_table_ren_columns = mis_val_table_ren_columns[
      mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
  '% of Total Values', ascending=False).round(1)
  
  # Print some summary information
  print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
      "There are " + str(mis_val_table_ren_columns.shape[0]) +
        " columns that have missing values.")
  
  # Return the dataframe with missing information
  return mis_val_table_ren_columns

# %%
def neat_preprocessing(text_in: str ) -> str:
  '''
  Funcao auxiliar que executa algumas etapas de limpeza em um dado texto usando a biblioteca neattext.
  - Remove tags HTML, URLs, pontuacoes, emails, numeros, simbolos de moeda, espaços multiplos
  - Substitue @usernames pela palavra "USER"
  - Substitue codigos de emogis pela palavra "EMOJI"

  Parameters:
    text_in (str): string de texto que sofrera o processo de limpeza.

  Returns:
    text: string de texto apos o processo de limpeza.
  '''
  import neattext.functions as ntx

  text = text_in.lower()
  
  # text = ntx.fix_contractions(text)
  text = ntx.remove_html_tags(text)
  text = ntx.remove_punctuations(text) 
  text = ntx.replace_term(text, ntx.USER_HANDLES_REGEX, 'USER')  
  text = ntx.remove_urls(text)
  text = ntx.remove_emails(text)
  text = ntx.remove_phone_numbers(text)
  text = ntx.remove_numbers(text)  
  text = ntx.replace_emojis(text, "EMOJI")
  text = ntx.remove_multiple_spaces(text)
  text = ntx.remove_currency_symbols(text)
  
  return text

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm.auto import tqdm

tqdm.pandas()

def parallel_applymap(df, func, worker_count, **kwargs):
  '''
  Funcao que paraleliza o metodo applymap do pandas

  Parameters:
    df (pd.DataFrame): dataframe no qual sera aplicado a funcao.
    func (callable):  funcao a ser aplicada a todas a celulas do dataframe.
    worker_count (int): quantidade de tarefas em paralelo que serão iniciadas. O dataframe sera subdividido em um numero = worker_count para cada tarefa processar.
    kwargs: demais parametros da funcao

  Returns:
    pd.Dataframe concatenado.
  '''
  def _apply(shard):
      return shard.progress_applymap(func, **kwargs)

  shards = np.array_split(df, worker_count)
  with ThreadPoolExecutor(max_workers=worker_count) as e:
      futures = e.map(_apply, shards)
  return pd.concat(list(futures))

# %% [markdown]
# ### Data gathering

# %% [markdown]
# The data gathering procedure was done through [Apify](https://apify.com/dtrungtin/airbnb-scraper/input-schema#locationQuery), a web scraping and automation platform.

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/IFSP/Trabalhos_Grupo_IFSP/NLP
# Out:
# /content/drive/MyDrive/Colab Notebooks/IFSP/Trabalhos_Grupo_IFSP/NLP

# %%
file_path = 'data/raw/'
file_name = 'dataset_airbnb-scraper_2023-04-04_01-45-49-997.csv'

df_raw = pd.read_csv(file_path + file_name, dtype=str)
print(f'No Rows: {df_raw.shape[0]}')
print(f'No Columns: {df_raw.shape[1]}', end='\n\n')
display(df_raw.head())
# Out:
# No Rows: 547
# No Columns: 1107
#   additionalHosts/0/about additionalHosts/0/badges/0  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#   additionalHosts/0/firstName additionalHosts/0/hasInclusionBadge  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
#
#   additionalHosts/0/hasProfilePic additionalHosts/0/hostUrl  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#   additionalHosts/0/id additionalHosts/0/isSuperHost  \
# 0                  NaN                           NaN
# 1                  NaN                           NaN
# 2                  NaN                           NaN
# 3                  NaN                           NaN
# 4                  NaN                           NaN
#
#   additionalHosts/0/languages/0 additionalHosts/0/languages/1  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   additionalHosts/0/languages/2 additionalHosts/0/languages/3  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   additionalHosts/0/languages/4 additionalHosts/0/memberSince  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   additionalHosts/0/pictureUrl additionalHosts/0/responseRate  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   additionalHosts/0/responseTime additionalHosts/0/smartName  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   additionalHosts/0/thumbnailUrl additionalHosts/1/about  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
#
#   additionalHosts/1/badges/0 additionalHosts/1/firstName  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   additionalHosts/1/hasInclusionBadge additionalHosts/1/hasProfilePic  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
#
#   additionalHosts/1/hostUrl additionalHosts/1/id  \
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
#
#   additionalHosts/1/isSuperHost additionalHosts/1/languages/0  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   additionalHosts/1/languages/1 additionalHosts/1/memberSince  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   additionalHosts/1/pictureUrl additionalHosts/1/responseRate  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   additionalHosts/1/responseTime additionalHosts/1/smartName  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   additionalHosts/1/thumbnailUrl additionalHosts/2/about  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
#
#   additionalHosts/2/firstName additionalHosts/2/hasInclusionBadge  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
#
#   additionalHosts/2/hasProfilePic additionalHosts/2/hostUrl  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#   additionalHosts/2/id additionalHosts/2/isSuperHost  \
# 0                  NaN                           NaN
# 1                  NaN                           NaN
# 2                  NaN                           NaN
# 3                  NaN                           NaN
# 4                  NaN                           NaN
#
#   additionalHosts/2/memberSince additionalHosts/2/pictureUrl  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   additionalHosts/2/smartName additionalHosts/2/thumbnailUrl  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#                                             address isAvailable  \
# 0                                 São Paulo, Brasil        true
# 1                        Guarujá, São Paulo, Brasil        true
# 2  Balneario Praia do Pernambuco, São Paulo, Brasil        true
# 3                    Gonzaguinha, São Paulo, Brasil        true
# 4                      Mairinque, São Paulo, Brasil        true
#
#   isHostedBySuperhost location/lat location/lng  \
# 0               false    -23.54374    -46.56514
# 1               false    -23.98499    -46.20439
# 2               false    -23.97859    -46.19105
# 3               false    -23.97002    -46.37333
# 4                true      -23.538      -47.186
#
#                                                 name numberOfGuests  \
# 0                       Ap 2q conforto e comodidade!              3
# 1  Apartamento Guarujá Praia Enseada Sp (GRUPO REIS)             10
# 2          Casa na Praia de Pernambuco, Guarujá - SP              6
# 3                                  Vista Maravilhosa              4
# 4                                    Chale do Caruso              6
#
#       photos/0/caption  \
# 0                  NaN
# 1                  NaN
# 2  Praia de Pernambuco
# 3                  NaN
# 4     Entrada do chalé
#
#                                                                                                              photos/0/pictureUrl  \
# 0                                  https://a0.muscache.com/im/pictures/38c35ac4-71d9-4674-a60c-348e1a8f85fc.jpg?aki_policy=large
# 1                                  https://a0.muscache.com/im/pictures/1063d0b4-22bb-4e6e-b3bb-d62499586e40.jpg?aki_policy=large
# 2                                  https://a0.muscache.com/im/pictures/3c0d7467-0719-4ae2-aa5c-7bc9abde348d.jpg?aki_policy=large
# 3                                  https://a0.muscache.com/im/pictures/07313e11-2a80-45fa-8ef6-e5cf05b0f884.jpg?aki_policy=large
# 4  https://a0.muscache.com/im/pictures/miso/Hosting-42037553/original/361787cd-7c70-41cc-838b-03d0373b2f10.jpeg?aki_policy=large
#
#                                                                                                            photos/0/thumbnailUrl  \
# 0                                  https://a0.muscache.com/im/pictures/38c35ac4-71d9-4674-a60c-348e1a8f85fc.jpg?aki_policy=small
# 1                                  https://a0.muscache.com/im/pictures/1063d0b4-22bb-4e6e-b3bb-d62499586e40.jpg?aki_policy=small
# 2                                  https://a0.muscache.com/im/pictures/3c0d7467-0719-4ae2-aa5c-7bc9abde348d.jpg?aki_policy=small
# 3                                  https://a0.muscache.com/im/pictures/07313e11-2a80-45fa-8ef6-e5cf05b0f884.jpg?aki_policy=small
# 4  https://a0.muscache.com/im/pictures/miso/Hosting-42037553/original/361787cd-7c70-41cc-838b-03d0373b2f10.jpeg?aki_policy=small
#
#   photos/1/caption  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 
\
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4        Sala de tv
#
#                                                                                                             photos/27/pictureUrl  \
# 0                                                                                                                            NaN
# 1                                  https://a0.muscache.com/im/pictures/2c6a2fe1-c028-45f2-9093-60b64c503fef.jpg?aki_policy=large
# 2                                                                                                                            NaN
# ...
# 3                                                                                                                                                                                                                                                                                                                                      NaN
# 4  a casa é exatamente como nas fotos, limpeza impecável, um lugar gostoso. No quintal tem uma churrasqueira, a decoração é de muito bom gosto. Todos os itens disponibilizados na casa funcionam perfeitamente e a Janine é muito gentil e ficou disponível a todo momento por mensagem. Super atenciosa e solicita. O lugar é muito bom.
#
#    reviews/18/createdAt       reviews/18/id reviews/18/language  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4  2021-09-05T18:29:29Z  444845947736941093                 NaN
#
#   reviews/18/localizedDate reviews/18/localizedReview  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4         setembro de 2021                        NaN
#
#   reviews/18/localizedReview/comments reviews/18/localizedReview/disclaimer  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#   reviews/18/localizedReview/needsTranslation  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   reviews/18/localizedReview/response reviews/18/rating  \
# 0                                 NaN               NaN
# 1                                 NaN               NaN
# 2                                 NaN               NaN
# 3                                 NaN               NaN
# 4                                 NaN                 5
#
#   reviews/18/recipient/firstName reviews/18/recipient/hasProfilePic  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4              Janine Pereira De                              false
#
#   reviews/18/recipient/id  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4               333122152
#
#                                                                                  reviews/18/recipient/pictureUrl  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4  https://a0.muscache.com/im/pictures/user/c2bfc985-db7b-444d-9091-83b714c36f12.jpg?aki_policy=profile_x_medium
#
#   reviews/18/recipient/smartName  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4              Janine Pereira De
#
#                                                                             reviews/18/recipient/thumbnailUrl  \
# 0                                                                                                         NaN
# 1                                                                                                         NaN
# 2                                                                                                         NaN
# 3                                                                                                         NaN
# 4  https://a0.muscache.com/im/pictures/user/c2bfc985-db7b-444d-9091-83b714c36f12.jpg?aki_policy=profile_small
#
#   reviews/18/response reviews/19/author/firstName  \
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                      Geneve
#
#   reviews/19/author/hasProfilePic reviews/19/author/id  \
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                           false            171768653
#
#                                                                                     reviews/19/author/pictureUrl  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4  https://a0.muscache.com/im/pictures/user/4beca6fb-39b7-48cd-8bd0-b95b25bfdf41.jpg?aki_policy=profile_x_medium
#
#   reviews/19/author/smartName  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                      Geneve
#
#                                                                                reviews/19/author/thumbnailUrl  \
# 0                                                                                                         NaN
# 1                                                                                                         NaN
# 2                                                                                                         NaN
# 3                                                                                                         NaN
# 4  https://a0.muscache.com/im/pictures/user/4beca6fb-39b7-48cd-8bd0-b95b25bfdf41.jpg?aki_policy=profile_small
#
#   reviews/19/collectionTag  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             reviews/19/comments  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# 4  O chalé parece um quarto de hotel 5 estrelas. Tem tudo que precisa para passar alguns dias, a limpeza estava impecável, cama e travesseiros muito confortáveis e bem cuidados, chuveiro a gás muito gostoso, sem contar com torneira de água quente que ajuda muito nos dias de frio, internet funciona muito bem para trabalho e a televisão funciona muitos canais. Janine muito atenciosa desde do momento da reserva, respondia sempre na mesma hora, deixou disponível jogos e mimos para não deixar faltar nada na hospedagem.<br/>Estrada de acesso ao condomínio tem uma parte de terra, mas com fácil acesso.<br/>Só tenho elogios para hospedagem.
#
#    reviews/19/createdAt       reviews/19/id reviews/19/language  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4  2021-08-22T17:13:32Z  434660861881579583                 NaN
#
#   reviews/19/localizedDate reviews/19/localizedReview  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4           agosto de 2021                        NaN
#
#   reviews/19/localizedReview/comments reviews/19/localizedReview/disclaimer  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#   reviews/19/localizedReview/needsTranslation  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   reviews/19/localizedReview/response reviews/19/rating  \
# 0                                 NaN               NaN
# 1                                 NaN               NaN
# 2                                 NaN               NaN
# 3                                 NaN               NaN
# 4                                 NaN                 5
#
#   reviews/19/recipient/firstName reviews/19/recipient/hasProfilePic  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4              Janine Pereira De                              false
#
#   reviews/19/recipient/id  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4               333122152
#
#                                                                                  reviews/19/recipient/pictureUrl  \
# 0                                                                                                            NaN
# 1                                                                                                            NaN
# 2                                                                                                            NaN
# 3                                                                                                            NaN
# 4  https://a0.muscache.com/im/pictures/user/c2bfc985-db7b-444d-9091-83b714c36f12.jpg?aki_policy=profile_x_medium
#
#   reviews/19/recipient/smartName  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4              Janine Pereira De
#
#                                                                             reviews/19/recipient/thumbnailUrl  \
# 0                                                                                                         NaN
# 1                                                                                                         NaN
# 2                                                                                                         NaN
# 3                                                                                                         NaN
# 4  https://a0.muscache.com/im/pictures/user/c2bfc985-db7b-444d-9091-83b714c36f12.jpg?aki_policy=profile_small
#
#   reviews/19/response                     roomType stars  \
# 0                 NaN         Espaço inteiro: loft   NaN
# 1                 NaN  Espaço inteiro: apartamento   NaN
# 2                 NaN         Espaço inteiro: casa     5
# 3                 NaN         Espaço inteiro: loft   NaN
# 4                 NaN        Espaço inteiro: chalé  4.96
#
#                                      url
# 0   https://www.airbnb.com/rooms/9386638
# 1  https://www.airbnb.com/rooms/39343119
# 2  https://www.airbnb.com/rooms/31208889
# 3  https://www.airbnb.com/rooms/53981045
# 4  https://www.airbnb.com/rooms/42037553

# %% [markdown]
# ### Step 01 - discarding information that doesn't matter

# %% [markdown]
# Removing columns relating to:
# - `additionalHosts`
# - property `photos` (we'll keep just first)
# - URL's
# - `primaryHost/languages` (we'll keep just first)

# %%
mask_additionalHosts = "df.columns.str.startswith('additionalHosts')"
mask_photos = "df.columns.str.contains(r'^photos/[^0]')"
mask_url = "df.columns.str.contains(r'^(?!photos).*Url$')"
mask_phlang = "df.columns.str.contains(r'^primaryHost/languages/[^0]')"
masks_commands = [mask_additionalHosts, mask_photos, mask_url, mask_phlang]

df_s01 = df_raw.pipe(remove_cols, masks_commands)

print(f'No Columns before step 01: {df_raw.shape[1]}')
print(f'No Columns after step 01: {df_s01.shape[1]}', end='\n\n')
df_s01.sample(1)
# Out:
# No Columns before step 01: 1107
# No Columns after step 01: 452
#                               address isAvailable isHostedBySuperhost  \
# 247  Vila Assuncao, São Paulo, Brasil        true               false
#
#     location/lat location/lng  \
# 247     -24.0267    -46.46928
#
#                                                    name numberOfGuests  \
# 247  Apto Pé na Areia na Praia Grande Ótima Localização              6
#
#     photos/0/caption  \
# 247              NaN
#
#                                                                                photos/0/pictureUrl  \
# 247  https://a0.muscache.com/im/pictures/b2f375fe-7681-4739-8cbf-148494e48010.jpg?aki_policy=large
#
#                                                                              photos/0/thumbnailUrl  \
# 247  https://a0.muscache.com/im/pictures/b2f375fe-7681-4739-8cbf-148494e48010.jpg?aki_policy=small
#
#     pricing/rate/amount pricing/rate/amountFormatted pricing/rate/currency  \
# 247                5000                      R$5.000                   BRL
#
#     pricing/rate/isMicrosAccuracy pricing/rateType primaryHost/about  \
# 247                         false          nightly               NaN
#
#       primaryHost/badges/0 primaryHost/badges/1 primaryHost/badges/2  \
# 247  Identidade verificada                  NaN                  NaN
#
#     primaryHost/firstName primaryHost/hasInclusionBadge  \
# 247              Marcello                         false
#
#     primaryHost/hasProfilePic primaryHost/id primaryHost/isSuperHost  \
# 247                      true      110640962                   false
#
#     primaryHost/languages/0       primaryHost/memberSince  \
# 247                     NaN  Membro desde janeiro de 2017
#
#     primaryHost/responseRate primaryHost/responseTime primaryHost/smartName  \
# 247                      NaN                      NaN              Marcello
#
#     reviews/0/author/firstName reviews/0/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/0/author/id reviews/0/author/smartName reviews/0/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/0/comments reviews/0/createdAt reviews/0/id reviews/0/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/0/localizedDate reviews/0/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/0/localizedReview/comments reviews/0/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/0/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/0/localizedReview/response reviews/0/rating  \
# 247                                NaN              NaN
#
#     reviews/0/recipient/firstName reviews/0/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/0/recipient/id reviews/0/recipient/smartName reviews/0/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/1/author/firstName reviews/1/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/1/author/id reviews/1/author/smartName reviews/1/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/1/comments reviews/1/createdAt reviews/1/id reviews/1/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/1/localizedDate reviews/1/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/1/localizedReview/comments reviews/1/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/1/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/1/localizedReview/response reviews/1/rating  \
# 247                                NaN              NaN
#
#     reviews/1/recipient/firstName reviews/1/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/1/recipient/id reviews/1/recipient/smartName reviews/1/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/2/author/firstName reviews/2/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/2/author/id reviews/2/author/smartName reviews/2/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/2/comments reviews/2/createdAt reviews/2/id reviews/2/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/2/localizedDate reviews/2/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/2/localizedReview/comments reviews/2/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/2/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/2/localizedReview/response reviews/2/rating  \
# 247                                NaN              NaN
#
#     reviews/2/recipient/firstName reviews/2/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/2/recipient/id reviews/2/recipient/smartName reviews/2/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/3/author/firstName reviews/3/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/3/author/id reviews/3/author/smartName reviews/3/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/3/comments reviews/3/createdAt reviews/3/id reviews/3/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/3/localizedDate reviews/3/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/3/localizedReview/comments reviews/3/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/3/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/3/localizedReview/response reviews/3/rating  \
# 247                                NaN              NaN
#
#     reviews/3/recipient/firstName reviews/3/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/3/recipient/id reviews/3/recipient/smartName reviews/3/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/4/author/firstName reviews/4/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/4/author/id reviews/4/author/smartName reviews/4/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/4/comments reviews/4/createdAt reviews/4/id reviews/4/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/4/localizedDate reviews/4/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/4/localizedReview/comments reviews/4/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/4/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/4/localizedReview/response reviews/4/rating  \
# 247                                NaN              NaN
#
#     reviews/4/recipient/firstName reviews/4/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/4/recipient/id reviews/4/recipient/smartName reviews/4/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/5/author/firstName reviews/5/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/5/author/id reviews/5/author/smartName reviews/5/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/5/comments reviews/5/createdAt reviews/5/id reviews/5/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/5/localizedDate reviews/5/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/5/localizedReview/comments reviews/5/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/5/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/5/localizedReview/response reviews/5/rating  \
# 247                                NaN              NaN
#
#     reviews/5/recipient/firstName reviews/5/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/5/recipient/id reviews/5/recipient/smartName reviews/5/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/6/author/firstName reviews/6/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/6/author/id reviews/6/author/smartName reviews/6/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/6/comments reviews/6/createdAt reviews/6/id reviews/6/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/6/localizedDate reviews/6/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/6/localizedReview/comments reviews/6/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/6/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/6/localizedReview/response reviews/6/rating  \
# 247                                NaN              NaN
#
#     reviews/6/recipient/firstName reviews/6/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/6/recipient/id reviews/6/recipient/smartName reviews/6/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/7/author/firstName reviews/7/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/7/author/id reviews/7/author/smartName reviews/7/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/7/comments reviews/7/createdAt reviews/7/id reviews/7/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/7/localizedDate reviews/7/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/7/localizedReview/comments reviews/7/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/7/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/7/localizedReview/response reviews/7/rating  \
# 247                                NaN              NaN
#
#     reviews/7/recipient/firstName reviews/7/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/7/recipient/id reviews/7/recipient/smartName reviews/7/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/8/author/firstName reviews/8/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/8/author/id reviews/8/author/smartName reviews/8/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/8/comments reviews/8/createdAt reviews/8/id reviews/8/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/8/localizedDate reviews/8/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/8/localizedReview/comments reviews/8/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/8/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/8/localizedReview/response reviews/8/rating  \
# 247                                NaN              NaN
#
#     reviews/8/recipient/firstName reviews/8/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/8/recipient/id reviews/8/recipient/smartName reviews/8/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/9/author/firstName reviews/9/author/hasProfilePic  \
# 247                        NaN                            NaN
#
#     reviews/9/author/id reviews/9/author/smartName reviews/9/collectionTag  \
# 247                 NaN                        NaN                     NaN
#
#     reviews/9/comments reviews/9/createdAt reviews/9/id reviews/9/language  \
# 247                NaN                 NaN          NaN                NaN
#
#     reviews/9/localizedDate reviews/9/localizedReview  \
# 247                     NaN                       NaN
#
#     reviews/9/localizedReview/comments reviews/9/localizedReview/disclaimer  \
# 247                                NaN                                  NaN
#
#     reviews/9/localizedReview/needsTranslation  \
# 247                                        NaN
#
#     reviews/9/localizedReview/response reviews/9/rating  \
# 247                                NaN              NaN
#
#     reviews/9/recipient/firstName reviews/9/recipient/hasProfilePic  \
# 247                           NaN                               NaN
#
#     reviews/9/recipient/id reviews/9/recipient/smartName reviews/9/response  \
# 247                    NaN                           NaN                NaN
#
#     reviews/10/author/firstName reviews/10/author/hasProfilePic  \
# 247                         NaN                             NaN
#
#     reviews/10/author/id reviews/10/author/smartName reviews/10/collectionTag  \
# 247                  NaN                         NaN                      NaN
#
#     reviews/10/comments reviews/10/createdAt reviews/10/id  \
# 247                 NaN                  NaN           NaN
#
#     reviews/10/language reviews/10/localizedDate reviews/10/localizedReview  \
# 247                 NaN                      NaN                        NaN
#
#     reviews/10/localizedReview/comments reviews/10/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/10/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/10/localizedReview/response reviews/10/rating  \
# 247                                 NaN               NaN
#
#     reviews/10/recipient/firstName reviews/10/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/10/recipient/id reviews/10/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/10/response reviews/11/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/11/author/hasProfilePic reviews/11/author/id  \
# 247                             NaN                  NaN
#
#     reviews/11/author/smartName reviews/11/collectionTag reviews/11/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/11/createdAt reviews/11/id reviews/11/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/11/localizedDate reviews/11/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/11/localizedReview/comments reviews/11/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/11/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/11/localizedReview/response reviews/11/rating  \
# 247                                 NaN               NaN
#
#     reviews/11/recipient/firstName reviews/11/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/11/recipient/id reviews/11/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/11/response reviews/12/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/12/author/hasProfilePic reviews/12/author/id  \
# 247                             NaN                  NaN
#
#     reviews/12/author/smartName reviews/12/collectionTag reviews/12/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/12/createdAt reviews/12/id reviews/12/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/12/localizedDate reviews/12/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/12/localizedReview/comments reviews/12/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/12/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/12/localizedReview/response reviews/12/rating  \
# 247                                 NaN               NaN
#
#     reviews/12/recipient/firstName reviews/12/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/12/recipient/id reviews/12/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/12/response reviews/13/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/13/author/hasProfilePic reviews/13/author/id  \
# 247                             NaN                  NaN
#
#     reviews/13/author/smartName reviews/13/collectionTag reviews/13/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/13/createdAt reviews/13/id reviews/13/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/13/localizedDate reviews/13/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/13/localizedReview/comments reviews/13/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/13/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/13/localizedReview/response reviews/13/rating  \
# 247                                 NaN               NaN
#
#     reviews/13/recipient/firstName reviews/13/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/13/recipient/id reviews/13/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/13/response reviews/14/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/14/author/hasProfilePic reviews/14/author/id  \
# 247                             NaN                  NaN
#
#     reviews/14/author/smartName reviews/14/collectionTag reviews/14/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/14/createdAt reviews/14/id reviews/14/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/14/localizedDate reviews/14/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/14/localizedReview/comments reviews/14/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/14/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/14/localizedReview/response reviews/14/rating  \
# 247                                 NaN               NaN
#
#     reviews/14/recipient/firstName reviews/14/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/14/recipient/id reviews/14/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/14/response reviews/15/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/15/author/hasProfilePic reviews/15/author/id  \
# 247                             NaN                  NaN
#
#     reviews/15/author/smartName reviews/15/collectionTag reviews/15/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/15/createdAt reviews/15/id reviews/15/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/15/localizedDate reviews/15/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/15/localizedReview/comments reviews/15/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/15/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/15/localizedReview/response reviews/15/rating  \
# 247                                 NaN               NaN
#
#     reviews/15/recipient/firstName reviews/15/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/15/recipient/id reviews/15/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/15/response reviews/16/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/16/author/hasProfilePic reviews/16/author/id  \
# 247                             NaN                  NaN
#
#     reviews/16/author/smartName reviews/16/collectionTag reviews/16/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/16/createdAt reviews/16/id reviews/16/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/16/localizedDate reviews/16/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/16/localizedReview/comments reviews/16/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/16/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/16/localizedReview/response reviews/16/rating  \
# 247                                 NaN               NaN
#
#     reviews/16/recipient/firstName reviews/16/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/16/recipient/id reviews/16/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/16/response reviews/17/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/17/author/hasProfilePic reviews/17/author/id  \
# 247                             NaN                  NaN
#
#     reviews/17/author/smartName reviews/17/collectionTag reviews/17/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/17/createdAt reviews/17/id reviews/17/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/17/localizedDate reviews/17/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/17/localizedReview/comments reviews/17/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/17/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/17/localizedReview/response reviews/17/rating  \
# 247                                 NaN               NaN
#
#     reviews/17/recipient/firstName reviews/17/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/17/recipient/id reviews/17/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/17/response reviews/18/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/18/author/hasProfilePic reviews/18/author/id  \
# 247                             NaN                  NaN
#
#     reviews/18/author/smartName reviews/18/collectionTag reviews/18/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/18/createdAt reviews/18/id reviews/18/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/18/localizedDate reviews/18/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/18/localizedReview/comments reviews/18/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/18/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/18/localizedReview/response reviews/18/rating  \
# 247                                 NaN               NaN
#
#     reviews/18/recipient/firstName reviews/18/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/18/recipient/id reviews/18/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/18/response reviews/19/author/firstName  \
# 247                 NaN                         NaN
#
#     reviews/19/author/hasProfilePic reviews/19/author/id  \
# 247                             NaN                  NaN
#
#     reviews/19/author/smartName reviews/19/collectionTag reviews/19/comments  \
# 247                         NaN                      NaN                 NaN
#
#     reviews/19/createdAt reviews/19/id reviews/19/language  \
# 247                  NaN           NaN                 NaN
#
#     reviews/19/localizedDate reviews/19/localizedReview  \
# 247                      NaN                        NaN
#
#     reviews/19/localizedReview/comments reviews/19/localizedReview/disclaimer  \
# 247                                 NaN                                   NaN
#
#     reviews/19/localizedReview/needsTranslation  \
# 247                                         NaN
#
#     reviews/19/localizedReview/response reviews/19/rating  \
# 247                                 NaN               NaN
#
#     reviews/19/recipient/firstName reviews/19/recipient/hasProfilePic  \
# 247                            NaN                                NaN
#
#     reviews/19/recipient/id reviews/19/recipient/smartName  \
# 247                     NaN                            NaN
#
#     reviews/19/response                     roomType stars  \
# 247                 NaN  Espaço inteiro: apartamento   NaN
#
#                                        url
# 247  https://www.airbnb.com/rooms/46828841

# %% [markdown]
# ### Step 02 - Evaluate Missing Values

# %%
missing_values_table(df_s01)
# Out:
# Your selected dataframe has 452 columns.
# There are 429 columns that have missing values.
#                                              Missing Values  % of Total Values
# reviews/2/collectionTag                                 547            100.000
# reviews/15/collectionTag                                547            100.000
# reviews/9/localizedReview                               547            100.000
# reviews/1/localizedReview                               547            100.000
# reviews/9/collectionTag                                 547            100.000
# reviews/14/collectionTag                                547            100.000
# reviews/8/localizedReview                               547            100.000
# reviews/18/localizedReview/response                     547            100.000
# reviews/14/localizedReview                              547            100.000
# reviews/18/localizedReview                              547            100.000
# reviews/8/collectionTag                                 547            100.000
# reviews/14/localizedReview/response                     547            100.000
# reviews/7/localizedReview                               547            100.000
# reviews/18/collectionTag                                547            100.000
# reviews/2/localizedReview                               547            100.000
# reviews/7/collectionTag                                 547            100.000
# reviews/10/collectionTag                                547            100.000
# reviews/15/localizedReview                              547            100.000
# reviews/4/localizedReview                               547            100.000
# reviews/5/collectionTag                                 547            100.000
# reviews/16/localizedReview                              547            100.000
# reviews/6/localizedReview                               547            100.000
# reviews/3/collectionTag                                 547            100.000
# reviews/17/localizedReview/response                     547            100.000
# reviews/3/localizedReview                               547            100.000
# reviews/17/localizedReview                              547            100.000
# reviews/6/collectionTag                                 547            100.000
# reviews/16/collectionTag                                547            100.000
# reviews/5/localizedReview                               547            100.000
# reviews/4/collectionTag                                 547            100.000
# reviews/1/collectionTag                                 547            100.000
# reviews/17/collectionTag                                547            100.000
# reviews/19/localizedReview/response                     547            100.000
# reviews/11/localizedReview                              547            100.000
# reviews/13/localizedReview                              547            100.000
# reviews/11/collectionTag                                547            100.000
# reviews/10/localizedReview                              547            100.000
# reviews/0/collectionTag                                 547            100.000
# reviews/19/localizedReview                              547            100.000
# reviews/19/collectionTag                                547            100.000
# reviews/12/collectionTag                                547            100.000
# reviews/0/localizedReview                               547            100.000
# reviews/13/collectionTag                                547            100.000
# reviews/12/localizedReview                              547            100.000
# reviews/13/localizedReview/response                     546             99.800
# reviews/12/localizedReview/response                     546             99.800
# reviews/6/localizedReview/response                      546             99.800
# reviews/11/localizedReview/response                     546             99.800
# reviews/10/localizedReview/response                     546             99.800
# reviews/5/localizedReview/response                      546             99.800
# reviews/9/localizedReview/response                      546             99.800
# reviews/8/localizedReview/response                      545             99.600
# reviews/3/localizedReview/response                      544             99.500
# reviews/1/localizedReview/response                      544             99.500
# reviews/4/localizedReview/response                      544             99.500
# reviews/16/localizedReview/response                     544             99.500
# reviews/2/localizedReview/response                      543             99.300
# reviews/0/localizedReview/response                      543             99.300
# reviews/7/localizedReview/response                      543             99.300
# reviews/15/localizedReview/response                     542             99.100
# primaryHost/badges/2                                    536             98.000
# reviews/4/localizedReview/comments                      535             97.800
# reviews/4/localizedReview/disclaimer                    535             97.800
# reviews/4/localizedReview/needsTranslation              535             97.800
# reviews/4/language                                      535             97.800
# reviews/3/localizedReview/comments                      532             97.300
# reviews/10/localizedReview/comments                     532             97.300
# reviews/3/language                                      531             97.100
# reviews/3/localizedReview/disclaimer                    531             97.100
# reviews/3/localizedReview/needsTranslation              531             97.100
# reviews/18/localizedReview/needsTranslation             531             97.100
# reviews/10/language                                     531             97.100
# reviews/2/localizedReview/comments                      531             97.100
# reviews/10/localizedReview/disclaimer                   531             97.100
# reviews/18/language                                     531             97.100
# reviews/18/localizedReview/comments                     531             97.100
# reviews/10/localizedReview/needsTranslation             531             97.100
# reviews/18/localizedReview/disclaimer                   531             97.100
# reviews/19/localizedReview/disclaimer                   530             96.900
# reviews/17/localizedReview/comments                     530             96.900
# reviews/9/localizedReview/needsTranslation              530             96.900
# reviews/9/localizedReview/disclaimer                    530             96.900
# reviews/9/localizedReview/comments                      530             96.900
# reviews/9/language                                      530             96.900
# reviews/17/language                                     530             96.900
# reviews/19/language                                     530             96.900
# reviews/19/localizedReview/comments                     530             96.900
# reviews/17/localizedReview/disclaimer                   530             96.900
# reviews/2/language                                      530             96.900
# reviews/17/localizedReview/needsTranslation             530             96.900
# reviews/2/localizedReview/disclaimer                    530             96.900
# reviews/19/localizedReview/needsTranslation             530             96.900
# reviews/2/localizedReview/needsTranslation              530             96.900
# reviews/5/localizedReview/comments                      529             96.700
# reviews/5/language                                      529             96.700
# reviews/6/localizedReview/needsTranslation              529             96.700
# reviews/5/localizedReview/disclaimer                    529             96.700
# reviews/5/localizedReview/needsTranslation              529             96.700
# reviews/6/language                                      529             96.700
# reviews/6/localizedReview/comments                      529             96.700
# reviews/6/localizedReview/disclaimer                    529             96.700
# reviews/13/localizedReview/needsTranslation             529             96.700
# reviews/15/localizedReview/comments                     529             96.700
# reviews/11/localizedReview/comments                     529             96.700
# reviews/12/localizedReview/comments                     529             96.700
# reviews/13/language                                     529             96.700
# reviews/13/localizedReview/comments                     529             96.700
# reviews/16/localizedReview/comments                     529             96.700
# reviews/13/localizedReview/disclaimer                   529             96.700
# reviews/0/localizedReview/comments                      529             96.700
# reviews/11/localizedReview/needsTranslation             528             96.500
# reviews/8/localizedReview/needsTranslation              528             96.500
# reviews/12/localizedReview/needsTranslation             528             96.500
# reviews/12/localizedReview/disclaimer                   528             96.500
# reviews/8/language                                      528             96.500
# reviews/8/localizedReview/comments                      528             96.500
# reviews/8/localizedReview/disclaimer                    528             96.500
# reviews/11/localizedReview/disclaimer                   528             96.500
# reviews/11/language                                     528             96.500
# reviews/12/language                                     528             96.500
# reviews/7/localizedReview/disclaimer                    527             96.300
# reviews/7/localizedReview/comments                      527             96.300
# reviews/15/language                                     527             96.300
# reviews/15/localizedReview/disclaimer                   527             96.300
# reviews/15/localizedReview/needsTranslation             527             96.300
# reviews/7/language                                      527             96.300
# reviews/14/localizedReview/needsTranslation             527             96.300
# reviews/7/localizedReview/needsTranslation              527             96.300
# reviews/14/localizedReview/disclaimer                   527             96.300
# reviews/14/localizedReview/comments                     527             96.300
# reviews/16/language                                     527             96.300
# reviews/14/language                                     527             96.300
# reviews/16/localizedReview/disclaimer                   527             96.300
# reviews/16/localizedReview/needsTranslation             527             96.300
# reviews/0/localizedReview/needsTranslation              526             96.200
# reviews/0/language                                      526             96.200
# reviews/0/localizedReview/disclaimer                    526             96.200
# reviews/18/response                                     524             95.800
# reviews/1/localizedReview/comments                      523             95.600
# reviews/1/language                                      522             95.400
# reviews/1/localizedReview/needsTranslation              522             95.400
# reviews/1/localizedReview/disclaimer                    522             95.400
# reviews/19/response                                     521             95.200
# reviews/16/response                                     519             94.900
# reviews/17/response                                     519             94.900
# reviews/9/response                                      518             94.700
# reviews/13/response                                     516             94.300
# reviews/8/response                                      516             94.300
# reviews/6/response                                      516             94.300
# reviews/12/response                                     515             94.100
# reviews/15/response                                     514             94.000
# reviews/7/response                                      514             94.000
# reviews/14/response                                     513             93.800
# reviews/11/response                                     513             93.800
# reviews/5/response                                      511             93.400
# reviews/10/response                                     510             93.200
# reviews/3/response                                      506             92.500
# reviews/4/response                                      501             91.600
# reviews/2/response                                      496             90.700
# reviews/1/response                                      491             89.800
# reviews/0/response                                      487             89.000
# reviews/19/author/hasProfilePic                         392             71.700
# reviews/19/localizedDate                                392             71.700
# reviews/19/id                                           392             71.700
# reviews/19/recipient/smartName                          392             71.700
# reviews/19/recipient/hasProfilePic                      392             71.700
# reviews/19/author/id                                    392             71.700
# reviews/19/author/smartName                             392             71.700
# reviews/19/rating                                       392             71.700
# reviews/19/comments                                     392             71.700
# reviews/19/recipient/id                                 392             71.700
# reviews/19/createdAt                                    392             71.700
# reviews/19/recipient/firstName                          392             71.700
# reviews/19/author/firstName                             392             71.700
# reviews/18/localizedDate                                387             70.700
# reviews/18/author/firstName                             387             70.700
# reviews/18/rating                                       387             70.700
# reviews/18/recipient/id                                 387             70.700
# reviews/18/recipient/smartName                          387             70.700
# reviews/18/author/smartName                             387             70.700
# reviews/18/id                                           387             70.700
# reviews/18/author/hasProfilePic                         387             70.700
# reviews/18/createdAt                                    387             70.700
# reviews/18/recipient/hasProfilePic                      387             70.700
# reviews/18/author/id                                    387             70.700
# reviews/18/comments                                     387             70.700
# reviews/18/recipient/firstName                          387             70.700
# reviews/17/recipient/id                                 382             69.800
# reviews/17/recipient/smartName                          382             69.800
# reviews/17/recipient/hasProfilePic                      382             69.800
# reviews/17/recipient/firstName                          382             69.800
# reviews/17/comments                                     382             69.800
# reviews/17/author/firstName                             382             69.800
# reviews/17/localizedDate                                382             69.800
# reviews/17/author/hasProfilePic                         382             69.800
# reviews/17/author/id                                    382             69.800
# reviews/17/author/smartName                             382             69.800
# reviews/17/createdAt                                    382             69.800
# reviews/17/id                                           382             69.800
# reviews/17/rating                                       382             69.800
# reviews/16/recipient/firstName                          377             68.900
# reviews/16/recipient/hasProfilePic                      377             68.900
# reviews/16/author/smartName                             377             68.900
# reviews/16/recipient/id                                 377             68.900
# reviews/16/recipient/smartName                          377             68.900
# reviews/16/localizedDate                                377             68.900
# reviews/5/recipient/id                                  282             51.600
# reviews/4/author/firstName                              274             50.100
# reviews/4/author/hasProfilePic                          274             50.100
# reviews/4/author/id                                     274             50.100
# reviews/4/createdAt                                     274             50.100
# reviews/4/author/smartName                              274             50.100
# reviews/4/comments                                      274             50.100
# reviews/4/recipient/firstName                           274             50.100
# reviews/4/id                                            274             50.100
# reviews/4/rating                                        274             50.100
# reviews/4/recipient/hasProfilePic                       274             50.100
# reviews/4/recipient/id                                  274             50.100
# reviews/4/recipient/smartName                           274             50.100
# reviews/4/localizedDate                                 274             50.100
# reviews/3/createdAt                                     258             47.200
# reviews/3/author/firstName                              258             47.200
# reviews/3/author/hasProfilePic                          258             47.200
# reviews/3/author/id                                     258             47.200
# reviews/3/author/smartName                              258             47.200
# reviews/3/comments                                      258             47.200
# reviews/3/id                                            258             47.200
# reviews/3/localizedDate                                 258             47.200
# reviews/3/rating                                        258             47.200
# reviews/3/recipient/firstName                           258             47.200
# reviews/3/recipient/hasProfilePic                       258             47.200
# reviews/3/recipient/id                                  258             47.200
# reviews/3/recipient/smartName                           258             47.200
# reviews/2/id                                            236             43.100
# reviews/2/author/hasProfilePic                          236             43.100
# reviews/2/author/id                                     236             43.100
# reviews/2/author/smartName                              236             43.100
# reviews/2/comments                                      236             43.100
# reviews/2/createdAt                                     236             43.100
# reviews/2/author/firstName                              236             43.100
# reviews/2/localizedDate                                 236             43.100
# reviews/2/recipient/id                                  236             43.100
# reviews/2/rating                                        236             43.100
# reviews/2/recipient/smartName                           236             43.100
# stars                                                   236             43.100
# reviews/2/recipient/hasProfilePic                       236             43.100
# reviews/2/recipient/firstName                           236             43.100
# reviews/1/createdAt                                     209             38.200
# reviews/1/recipient/smartName                           209             38.200
# reviews/1/author/hasProfilePic                          209             38.200
# reviews/1/author/id                                     209             38.200
# reviews/1/author/smartName                              209             38.200
# reviews/1/comments                                      209             38.200
# reviews/1/author/firstName                              209             38.200
# reviews/1/id                                            209             38.200
# reviews/1/rating                                        209             38.200
# reviews/1/recipient/firstName                           209             38.200
# reviews/1/recipient/hasProfilePic                       209             38.200
# reviews/1/recipient/id                                  209             38.200
# reviews/1/localizedDate                                 209             38.200
# reviews/0/createdAt                                     161             29.400
# reviews/0/author/firstName                              161             29.400
# reviews/0/author/hasProfilePic                          161             29.400
# reviews/0/author/id                                     161             29.400
# reviews/0/author/smartName                              161             29.400
# reviews/0/comments                                      161             29.400
# reviews/0/id                                            161             29.400
# reviews/0/localizedDate                                 161             29.400
# reviews/0/rating                                        161             29.400
# reviews/0/recipient/firstName                           161             29.400
# reviews/0/recipient/id                                  161             29.400
# reviews/0/recipient/smartName                           161             29.400
# reviews/0/recipient/hasProfilePic                       161             29.400
# primaryHost/responseTime                                145             26.500
# primaryHost/responseRate                                145             26.500
# primaryHost/badges/1                                    109             19.900
# primaryHost/badges/0                                     17              3.100

# %% [markdown]
# ### Step 03 - discarding information based on missing values

# %% [markdown]
# keeping only the following columns about reviews:
# - Review: `comments`, `createdAt`, `id`, `rating`
# - Review Author: `firstName`, `id`

# %%
mask_reviews_data = "df.columns.str.contains(r'^reviews/[0-9]+/(?!author/)(?!comments|createdAt|id|rating)')"
mask_author_data = "df.columns.str.contains(r'^reviews/[0-9]+/author/(?!firstName|id)')"
masks_commands = [mask_reviews_data, mask_author_data]

df_s03 = df_s01.pipe(remove_cols, masks_commands)

print(f'No Columns before step 02: {df_s01.shape[1]}')
print(f'No Columns after step 02: {df_s03.shape[1]}', end='\n\n')
df_s03.sample(1)
# Out:
# No Columns before step 02: 452
# No Columns after step 02: 152
#                address isAvailable isHostedBySuperhost location/lat  \
# 434  São Paulo, Brasil        true               false    -23.62425
#
#     location/lng                              name numberOfGuests  \
# 434    -46.67702  Impecavel, localização excelente              2
#
#     photos/0/caption  \
# 434   Living Comedor
#
#                                                                                photos/0/pictureUrl  \
# 434  https://a0.muscache.com/im/pictures/f3b32b0d-2b3c-4984-b2f2-02c979ec2ad5.jpg?aki_policy=large
#
#                                                                              photos/0/thumbnailUrl  \
# 434  https://a0.muscache.com/im/pictures/f3b32b0d-2b3c-4984-b2f2-02c979ec2ad5.jpg?aki_policy=small
#
#     pricing/rate/amount pricing/rate/amountFormatted pricing/rate/currency  \
# 434                1200                      R$1.200                   BRL
#
#     pricing/rate/isMicrosAccuracy pricing/rateType primaryHost/about  \
# 434                         false          nightly               NaN
#
#     primaryHost/badges/0   primaryHost/badges/1 primaryHost/badges/2  \
# 434         5 avaliações  Identidade verificada                  NaN
#
#     primaryHost/firstName primaryHost/hasInclusionBadge  \
# 434               Bettina                         false
#
#     primaryHost/hasProfilePic primaryHost/id primaryHost/isSuperHost  \
# 434                      true       31878709                   false
#
#     primaryHost/languages/0     primaryHost/memberSince  \
# 434                 English  Membro desde abril de 2015
#
#     primaryHost/responseRate primaryHost/responseTime primaryHost/smartName  \
# 434                     100%         dentro de um dia               Bettina
#
#     reviews/0/author/firstName reviews/0/author/id  \
# 434                      Fabio            27836142
#
#                                                                                                                                                        reviews/0/comments  \
# 434  O apartamento e muito legal, arrumado , varanda bacana , mobilia bonita , piscina gostosa , gostei muito estendi minha estadia por muito mais tempo , tudo completo
#
#       reviews/0/createdAt reviews/0/id reviews/0/rating  \
# 434  2015-12-01T14:51:10Z     55397518                5
#
#     reviews/1/author/firstName reviews/1/author/id  \
# 434                      Fabio            27836142
#
#                                                                                                                                                                                                                                                                                                                                                                            reviews/1/comments  \
# 434  Apartamento muito arrumado e bonito , gostei muito da varanda , possui todos os utensílios de cozinha e o prédio possui um ótimo astral com moradores novos mas definitivamente o melhor de tudo 'e a piscina na cobertura . Quanto a Betina ela foi muito amável e atenciosa , recomendo , inclusive pretendo extender minha estadia e quando voltar ao Brasil ficar aqui novamente ...
#
#       reviews/1/createdAt reviews/1/id reviews/1/rating  \
# 434  2015-10-05T14:18:15Z     49634718                4
#
#     reviews/2/author/firstName reviews/2/author/id  \
# 434                     Martín            33993214
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     reviews/2/comments  \
# 434  Bettina fue muy amable y atenta tanto en el check-in como check-out. Es el lugar en el que más cómodo me he sentido, está totalmente amueblado, todos los elementos son de excelente calidad, limpio, ordenado, espacioso.. tiene 2 aires acondicionados, 2 smart tv y Wifi que funcionan a la perfección, los vecinos son muy atentos y amables, el lugar es extremadamente seguro. Las instalaciones del predio (home office, gimnasio, piscina, sauna) son excelentes. El apto de Bettina es la mejor opción!!
#
#       reviews/2/createdAt reviews/2/id reviews/2/rating  \
# 434  2016-03-16T10:11:52Z     65686846                5
#
#     reviews/3/author/firstName reviews/3/author/id reviews/3/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/3/createdAt reviews/3/id reviews/3/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/4/author/firstName reviews/4/author/id reviews/4/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/4/createdAt reviews/4/id reviews/4/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/5/author/firstName reviews/5/author/id reviews/5/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/5/createdAt reviews/5/id reviews/5/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/6/author/firstName reviews/6/author/id reviews/6/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/6/createdAt reviews/6/id reviews/6/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/7/author/firstName reviews/7/author/id reviews/7/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/7/createdAt reviews/7/id reviews/7/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/8/author/firstName reviews/8/author/id reviews/8/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/8/createdAt reviews/8/id reviews/8/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/9/author/firstName reviews/9/author/id reviews/9/comments  \
# 434                        NaN                 NaN                NaN
#
#     reviews/9/createdAt reviews/9/id reviews/9/rating  \
# 434                 NaN          NaN              NaN
#
#     reviews/10/author/firstName reviews/10/author/id reviews/10/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/10/createdAt reviews/10/id reviews/10/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/11/author/firstName reviews/11/author/id reviews/11/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/11/createdAt reviews/11/id reviews/11/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/12/author/firstName reviews/12/author/id reviews/12/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/12/createdAt reviews/12/id reviews/12/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/13/author/firstName reviews/13/author/id reviews/13/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/13/createdAt reviews/13/id reviews/13/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/14/author/firstName reviews/14/author/id reviews/14/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/14/createdAt reviews/14/id reviews/14/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/15/author/firstName reviews/15/author/id reviews/15/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/15/createdAt reviews/15/id reviews/15/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/16/author/firstName reviews/16/author/id reviews/16/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/16/createdAt reviews/16/id reviews/16/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/17/author/firstName reviews/17/author/id reviews/17/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/17/createdAt reviews/17/id reviews/17/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/18/author/firstName reviews/18/author/id reviews/18/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/18/createdAt reviews/18/id reviews/18/rating  \
# 434                  NaN           NaN               NaN
#
#     reviews/19/author/firstName reviews/19/author/id reviews/19/comments  \
# 434                         NaN                  NaN                 NaN
#
#     reviews/19/createdAt reviews/19/id reviews/19/rating  \
# 434                  NaN           NaN               NaN
#
#                        roomType stars                                   url
# 434  Espaço inteiro: condomínio  4.67  https://www.airbnb.com/rooms/8033789

# %% [markdown]
# ### Step 04 - Getting text columns from dataframe

# %%
# Definindo as  colunas de texto
mask_text_cols = "df.columns.str.contains(r'name|about|comments')"
df_txt_cols = df_s03.pipe(remove_cols, [mask_text_cols], inverse=False)
df_txt_cols.sample(1)
# Out:
#                                   name primaryHost/about  \
# 27  Loft República/Viera Carvalho (ad)               NaN
#
#                                                                                     reviews/0/comments  \
# 27  Ademar foi super solícito e me ajudou em tudo que foi necessário. Extremamente simpático e gentil.
#
#    reviews/1/comments reviews/2/comments reviews/3/comments  \
# 27                NaN                NaN                NaN
#
#    reviews/4/comments reviews/5/comments reviews/6/comments  \
# 27                NaN                NaN                NaN
#
#    reviews/7/comments reviews/8/comments reviews/9/comments  \
# 27                NaN                NaN                NaN
#
#    reviews/10/comments reviews/11/comments reviews/12/comments  \
# 27                 NaN                 NaN                 NaN
#
#    reviews/13/comments reviews/14/comments reviews/15/comments  \
# 27                 NaN                 NaN                 NaN
#
#    reviews/16/comments reviews/17/comments reviews/18/comments  \
# 27                 NaN                 NaN                 NaN
#
#    reviews/19/comments
# 27                 NaN

# %%
arr_texts = df_txt_cols.fillna('').values
arr_texts[:5]
# Out:
# array([['Ap 2q conforto e comodidade!', '',
#         'The host canceled this reservation 107 days before arrival. This is an automated posting.',
#         '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#         '', '', ''],
#        ['Apartamento Guarujá Praia Enseada Sp (GRUPO REIS)', '', '', '',
#         '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#         '', ''],
#        ['Casa na Praia de Pernambuco, Guarujá - SP', '',
#         'A casa fica bem próxima da praia, além disso a casa é uma graça, tudo muito limpo e organizado. Os anfritriões são muito atenciosos. Recomendo, voltaremos mais vezes!',
#         'Um lugar lindo e próximo a praia, da para ir de a pé.  Cristian e dona Maria super atenciosos e cuidadosos conosco. Casa super limpa e com utensílios que dá para cozinhar sem problemas. A praia é de água limpa e bem familiar. Amamos o lugar e pretendemos voltar mais vezes.  Valeu muito a pena !',
#         'Cristian e Dona Maria excelentes anfitriões! <br/>Super flexibilizaram o check out e gostaríamos de ter ficado mais rs',
#         'Casa extremamente limpa e muito bem cuidada igualzinha as fotos!!! Sem falar na hospitalidade da dona Maria ela é amor... Com certeza voltarei!',
#         'Lugar muito limpo e casa bastante espaçosa. O valor também é ótimo pelo que é oferecido. O Cristian foi muito  prestativo e nos ajudou com o check in, ajustando para os horários que pretendíamos chegar e sair. Recomendo!',
#         'Ótima estadia, lugar muito tranquilo, muito bom!',
#         'Chalé muito confortável, bem decorado. Lugar sensacional com lazer completo.',
#         'Janine me atendeu super bem e rapidamente durante todo o período do antes, durante e pós estadia. Foi flexível em diversos pontos, tendo foco na satisfação dos hóspedes. Infelizmente, tivemos intercorrência com vizinhos barulhentos e som alto na área da piscina, coisas que não estavam sob o controle da anfitriã. No entanto, Janine resolveu esses inconvenientes de forma rápida. <br/>A casa é bem mais bonita e espaçosa do que nas fotos. Limpeza impecável. Clima super agradável. Ficamos encantados.',
#         'Janine ótima comunicação,  casa super equipada muito limpa com áreas de lazer do condomínio muito boa . Ambiente para descanso e trabalho e familiar.',
#         'Simplesmente maravilhoso! estadia perfeita , melhor que o anúncio. Ótima infraestrutura no condomínio e segurança. Chalé lindo, nos sentimos em casa, Internet, Netflix, amazon prime. Janine ótima anfitriã,  atenciosa e muito prestativa. Super indico. Voltaremos com certeza.',
#         'Ambiente muito agradável, organizado e limpo. Tudo conforme o anúncio.<br/>Gostamos muito da área da piscina e recreação. <br/>A anfitriã foi muito atenciosa e prestativa. Recomendamos !',
#         'Chalé maravilhoso, recepção incrível, anfitrião muito simpática e prestativa, Chalé impecável e completissimo! Me senti em casa e muito bem recebida.',
#         'Recomendo. O chale é um encanto. super equipado e tem tuuudo que imaginar. o condomínio é super tranquilo e silencioso. Piscina enorme e maravilhosa.Janine super atenciosa e preocupada com tudo. Parabéns pelo cuidado, capricho e carinho. voltaremos ❤',
#         'Excelente chalé, tudo muito limpo e organizado! Internet de boa qualidade, um verdadeira extensão de nossas casas. A anfitriã é muito atenciosa e pensa em todos os detalhes, não senti falta de nada durante o período da hospedagem.',
#         'a casa é exatamente como nas fotos, limpeza impecável, um lugar gostoso. No quintal tem uma churrasqueira, a decoração é de muito bom gosto. Todos os itens disponibilizados na casa funcionam perfeitamente e a Janine é muito gentil e ficou disponível a todo momento por mensagem. Super atenciosa e solicita. O lugar é muito bom.',
#         'O chalé parece um quarto de hotel 5 estrelas. Tem tudo que precisa para passar alguns dias, a limpeza estava impecável, cama e travesseiros muito confortáveis e bem cuidados, chuveiro a gás muito gostoso, sem contar com torneira de água quente que ajuda muito nos dias de frio, internet funciona muito bem para trabalho e a televisão funciona muitos canais. Janine muito atenciosa desde do momento da reserva, respondia sempre na mesma hora, deixou disponível jogos e mimos para não deixar faltar nada na hospedagem.<br/>Estrada de acesso ao condomínio tem uma parte de terra, mas com fácil acesso.<br/>Só tenho elogios para hospedagem.']],
#       dtype=object)

# %% [markdown]
# ### Step 05 - Defining preprocessing and cleaning operations

# %%
if LANG == 'english':
  stanza_lang = 'en'
  spacy_pipe = 'en_core_web_lg'
  
elif LANG == 'portuguese':
  stanza_lang = 'pt'
  spacy_pipe = 'pt_core_news_lg'
  
else:
  print('Antes de continuar, defina a variavel LANG = "portuguese" | "english"')

# %%
from urllib.request import Request, urlopen 

req = Request(f'https://countwordsfree.com/stopwords/{LANG}/txt')
req.add_header('User-Agent', 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0')
content = urlopen(req)
stop_words = pd.read_csv(content, header=None)
stop_words = stop_words[0].values

# %%
# !python -m spacy download {spacy_pipe}
# Out:
# 2023-04-13 14:28:18.518980: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 14:28:19.727640: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-04-13 14:28:21.247541: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-13 14:28:21.247990: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-13 14:28:21.248172: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from en-core-web-lg==3.5.0) (3.5.2)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (23.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (67.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.22.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
from functools import cache
from typing import Union
import spacy
spacy.prefer_gpu()
import stanza


stanza.download(stanza_lang)
nlp_spacy = spacy.load(spacy_pipe, disable=['parser', 'ner', 'textcat']) 
spacy_type = type(nlp_spacy)

@cache
def preprocess_txt(textraw:str, nlp_obj:Union[spacy_type, stanza.pipeline.core.Pipeline], lemma=False) -> str:
  '''
  Realiza a limpeza e o pre processamento de um dado texto em portugues.
  As etapas de pré-processamento a serem executadas são:
  * Conversão para Minúsculas.
  * Remocao de tags HTML.
  * Remocao de pontuacoes.
  * Remocao de algarismos numericos e numeros de telefone.
  * Remocao de multiplos espacos.
  * Remocao de URLs e E-mails: são removidos, pois eles não adicionam significado ao texto.
  * Substituicao de Emojis: Substitui emojis usando um dicionário predefinido contendo emojis junto com seu significado. (por exemplo: ":)" para "sorriso")
  * Substituindo nomes de usuário: Substitua @Usernames pela palavra "USER". (por exemplo: "@nick_name" para "USER")
  * Remocao de ascentuacao.
  * Removendo Não-Alfabetos: Substitui caracteres (exceto Dígitos e Alfabetos) por um espaço.
  * Removendo letras consecutivas: 3 ou mais letras consecutivas são substituídas por 2 letras. (por exemplo: "Muitoooo" para "Muitoo")
  * Remoção de palavras curtas: palavras com comprimento menor que 2 são removidas.
  * Removendo Stopwords: Stopwords são as palavras que não adicionam muito significado a uma frase. Eles podem ser ignorados com segurança sem sacrificar o significado da frase. (por exemplo: "the", "he", "have")
  * Lematização: A lematização é o processo de converter uma palavra em sua forma básica. (por exemplo: “Great” para “Good”). A lematização geralmente retorna palavras válidas (que existem) enquanto as técnicas de stemming retornam (na maioria das vezes) palavras abreviadas

  Parameters:
    textraw (str): texto bruto o qual sofrera as operacoes de limpeza e pre processamento.
    nlp_obj (spacy.lang.pt.Portuguese | spacy.lang.en.English | stanza.pipeline.core.Pipeline): - objeto que indica a biblioteca a ser utilizada para a etapa de tokenizacao, remocao de stop words e lemmatizacao.
    lemma (boolean): (opcional) se deve substituir as palavras originais do texto por seu lemma ou nao. Default: False

  Returns:
    wordsclean (pd.Dataframe): dataframe sem as colunas indicadas na máscara
  '''
  import re
  from unidecode import unidecode
  # from gensim.utils import simple_preprocess
  
  global stop_words

  # Definindo padrões Regex
  # urlPattern        = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
  # userPattern       = '@[^\s]+'
  alphaPattern      = "[^a-zA-Z0-9]"
  sequencePattern   = r"(.)\1\1+" # letras consecutivas
  seqReplacePattern = r"\1\1"
  
  # Definindo dicionario de emojis e seus respectivos significados
  emojis = {':)': 'sorri', ':-)': 'sorri', ';d': 'pisca', ':-E': 'vampiro', ':(': 'triste', 
            ':-(': 'triste', ':-<': 'triste', ':P': 'mostra lingua', ':O': 'surpresa',
            ':-@': 'chocado', ':@': 'chocado',':-$': 'confuso', ':\\': 'irritado', 
            ':#': 'mudo', ':X': 'mudo', ':^)': 'sorri', ':-&': 'confuso', '$_$': 'ganancia',
            '@@': 'vira os olhos', ':-!': 'confuso', ':-D': 'sorri', ':-0': 'grita', 'O.o': 'confuso',
            '<(-_-)>': 'robo', 'd[-_-]b': 'dj', ":'-)": 'sorri triste', ';)': 'piscar', 
            ';-)': 'piscar', 'O:-)': 'anjo','O*-)': 'anjo','(:-D': 'fofoca', '=^.^=': 'gato'}

   
  # ##################
  # Tentativa de aplicação de técnica para correção de palavras com erro de escrita, 
  # mas o resultado não foi considerado satisfatório.
  # ##################
  # from gensim.utils import simple_tokenize
  # from spellchecker import SpellChecker
  # spell = SpellChecker(language='pt')
  # wordlist = list(simple_tokenize(textraw))
  # misspelled = spell.unknown(wordlist)
  # correctedtext = [spell.correction(word) for word in misspelled]
  # print(correctedtext)

  textclean = neat_preprocessing(textraw)  
  for emoji in emojis.keys():
      textclean = textclean.replace(emoji, "EMOJI" + emojis[emoji])  
  textclean = re.sub(sequencePattern, seqReplacePattern, textclean)
  textclean = unidecode(textclean)
  textclean = re.sub(alphaPattern, " ", textclean)
  wordsclean = ''

  if nlp_obj.__module__ == 'spacy.lang.en' or nlp_obj.__module__ == 'spacy.lang.pt':
    doc = nlp_obj(textclean)
    for token in doc:      
      if not token.is_stop and len(token) > 1:
        if lemma and token.pos_ == 'VERB':
          wordsclean += token.lemma_+' '
        else:
          wordsclean += token.text + ' '

  elif isinstance(nlp_obj, stanza.pipeline.core.Pipeline):
    doc = nlp_obj(textclean)
    for sent in doc.sentences:
      for word in sent.words:   
        if word.text not in stop_words and len(word.text) > 1:   
          if lemma and word.upos == 'VERB':
            wordsclean += word.lemma +' '
          else:
            wordsclean += word.text + ' '
  else:
      raise BaseException('Instancia nao reconhecida do objeto "nlp_obj". Opcoes: spacy | stanza')
    
  return wordsclean
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: en (English) ...
# INFO:stanza:File exists: /root/stanza_resources/en/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.

# %% [markdown]
# ### Step 06 - Tests

# %%
arr_texts[133]
# Out:
# array(['Casa de Veraneio na Praia de Pernambuco', '',
#        'A casa é perfeita para reunir a família com segurança e sossego. <br/>São cinco suítes que oferecem privacidade para todos os hóspedes. <br/>Reunimos 13 familiares  num ambiente gostoso com uma piscina maravilhosa e limpa, inclusive com som  ambiente. <br/>O ar condicionado é muito eficiente em todos os quartos. A Edna cozinha divinamente, e o Mauro deixa as dependências imaculadas. Ela nos fez uma lula à dorè dos deuses ! Super crocantes ! A caipirinha do Mauro é digno de um  barman!<br/>Recomendo sem restrições!!!',
#        'Mesmo sem conhecer pessoalmente a Carolina ela sempre foi muito educada, simpática e rápida/eficiente nas respostas. A casa superou todas as nossas expectativas, o local é enorme e acomodou confortavelmente as 14 pessoas que viajaram comigo. Os caseiros ficaram todo o tempo na casa e nos ajudaram com algumas tarefas do dia a dia, com destaque para o Feijão da Edna e o Churrasco do Mauro. Está nos meus planos voltar em breve para passar mais alguns dias.',
#        'Carolina’s home was incredible. The house and property are even more beautiful in person than in the pictures. The house and pool were perfect for our multigenerational family and art lovers. There were multiple lounge, game and play areas. The beach was just a few blocks away and many other stunning beaches to visit were a short drive away. Understanding how to work with the Caseros was a bit of a learning curve because we did not speak portugués and were not accustomed to having them but after a day or two we figured it out and Mauro & Edna were fantastic. One thing that could be improved is the wifi did not extend throughout the entire house. Would highly recommend Carolina’s property and hope to visit again!',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''],
#       dtype=object)

# %% [markdown]
# #### Teste Spacy

# %%
# %%time

postprocess = []
for rawtxt in arr_texts[133]:
  if len(rawtxt):
    postprocess.append(preprocess_txt(rawtxt, nlp_obj=nlp_spacy, lemma=True))

postprocess
# Out:
# CPU times: user 608 ms, sys: 205 ms, total: 813 ms
# Wall time: 845 ms
# ['casa de veraneio na praia de pernambuco ',
#  'casa perfeita para reunir familia com seguranca sossego sao cinco suites que oferecem privacidade para todos os hospedes reunimos familiares num ambiente gostoso com uma piscina maravilhosa limpa inclusive com som ambiente ar condicionado muito eficiente em todos os quartos edna cozinha divinamente mauro deixa dependencias imaculadas ela nos fez uma lula dore dos deuse super crocantes caipirinha mauro digno de um barmanrecomendo sem restricoes ',
#  'mesmo sem conhecer pessoalmente carolina ela sempre foi muito educada simpatica rapida eficiente nas resposta casa superou todas nossas expectativas local enorme acomodou confortavelmente pessoas que viajaram comigo os caseiros ficaram todo tempo na casa nos ajudaram com algumas tarefas dia dia com destaque para feijao da edna churrasco mauro esta nos meus planos voltar em breve para passar mais alguns dias ',
#  'carolina home incredible house property beautiful person pictures house pool perfect multigenerational family art lovers multiple lounge game play areas beach blocks away stunning beaches visit short drive away understand work caseros bit learning curve speak portugues accustomed have day figure mauro edna fantastic thing improve wifi extend entire house highly recommend carolina property hope visit ']

# %% [markdown]
# ####  Teste Stanza

# %%
# %%time
########## Stanza defined's processors for this task:
# tokenize - Segments a Document into Sentences, each containing a list of Tokens.
# mwt - Expands multi-word tokens (MWTs) into multiple words when they are predicted by the tokenizer.Fix contractions.
# pos - UPOS, XPOS, and UFeats annotations are accessible through Word’s properties `pos`, `xpos`, and `ufeats`.
# lemma - Perform lemmatization on a Word using the `Word.text` and `Word.upos` values. The result can be accessed as `Word.lemma`. 
nlp_stanza = stanza.Pipeline(lang=stanza_lang, processors='tokenize,mwt,pos,lemma', use_gpu=True, download_method=None, verbose=False, max_cache_size=2)
postprocess = []
for rawtxt in arr_texts[133]:
  if len(rawtxt):
    postprocess.append(preprocess_txt(rawtxt, nlp_obj=nlp_stanza, lemma=True))

postprocess
# Out:
# CPU times: user 1.1 s, sys: 234 ms, total: 1.34 s
# Wall time: 1.79 s
# ['casa veraneio praia pernambuco ',
#  'casa perfeita para reunir familia seguranca sossego sao cinco suites oferecem privacidade para todos os hospedes reunimos familiares num ambiente gostoso uma piscina maravilhosa limpa inclusive som ambiente ar condicionado muito eficiente em todos os quartos edna cozinha divinamente mauro deixa dependencias imaculadas ela fez uma lula dore dos deuses super crocantes caipirinha mauro digno um barmanrecomendo sem restricoes ',
#  'mesmo sem conhecer pessoalmente carolina ela sempre foi muito educada simpatica rapida eficiente nas respostas casa superou todas nossas expectativas local enorme acomodou confortavelmente pessoas viajaram comigo os caseiros ficaram todo tempo casa ajudaram algumas tarefas dia dia destaque para feijao da edna churrasco mauro esta meus planos voltar em breve para passar mais alguns dias ',
#  'carolina incredible house property beautiful person pictures house pool perfect multigenerational family art lovers multiple lounge game play areas beach blocks stunning beaches visit short drive understand work caseros bit learning curve speak portugues accustomed day figure mauro edna fantastic improve wifi extend entire house highly recommend carolina property hope visit ']

# %% [markdown]
# ### Step 07 - Applying preprocessing operations on dataframe text columns

# %% [markdown]
# #### Using SpaCy

# %%
# %%time
df_txt_cols_processed_spacy = parallel_applymap(df_txt_cols, preprocess_txt, worker_count=10, na_action='ignore', nlp_obj=nlp_spacy, lemma=True)
# Out:
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1188 [00:00<?, ?it/s]
#   0%|          | 0/1188 [00:00<?, ?it/s]
#   0%|          | 0/1188 [00:00<?, ?it/s]
# CPU times: user 1min 40s, sys: 9.3 s, total: 1min 50s
# Wall time: 1min 55s

# %%
df_txt_cols_processed_spacy.loc[133:134]
# Out:
#                                          name  \
# 133  casa de veraneio na praia de pernambuco
# 134                      alto padrao jardins
#
#                         primaryHost/about  \
# 133                                   NaN
# 134  engenheiro empresario casado filhos
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    reviews/0/comments  \
# 133  casa perfeita para reunir familia com seguranca sossego sao cinco suites que oferecem privacidade para todos os hospedes reunimos familiares num ambiente gostoso com uma piscina maravilhosa limpa inclusive com som ambiente ar condicionado muito eficiente em todos os quartos edna cozinha divinamente mauro deixa dependencias imaculadas ela nos fez uma lula dore dos deuse super crocantes caipirinha mauro digno de um barmanrecomendo sem restricoes
# 134                                                                                                                                                                                                                                                                                                                                                                  gil apartment fantastic location great apartment spacious cozy gil helpful kind recommend place
#
#                                                                                                                                                                                                                                                                                                                                                                                                               reviews/1/comments  \
# 133  mesmo sem conhecer pessoalmente carolina ela sempre foi muito educada simpatica rapida eficiente nas resposta casa superou todas nossas expectativas local enorme acomodou confortavelmente pessoas que viajaram comigo os caseiros ficaram todo tempo na casa nos ajudaram com algumas tarefas dia dia com destaque para feijao da edna churrasco mauro esta nos meus planos voltar em breve para passar mais alguns dias
# 134                                                                                                                                                                                                                                                                                                                                                                                                                          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                       reviews/2/comments  \
# 133  carolina home incredible house property beautiful person pictures house pool perfect multigenerational family art lovers multiple lounge game play areas beach blocks away stunning beaches visit short drive away understand work caseros bit learning curve speak portugues accustomed have day figure mauro edna fantastic thing improve wifi extend entire house highly recommend carolina property hope visit
# 134                                                                                                                                                                                                                                                                                                                                                                                                                  NaN
#
#     reviews/3/comments reviews/4/comments reviews/5/comments  \
# 133                NaN                NaN                NaN
# 134                NaN                NaN                NaN
#
#     reviews/6/comments reviews/7/comments reviews/8/comments  \
# 133                NaN                NaN                NaN
# 134                NaN                NaN                NaN
#
#     reviews/9/comments reviews/10/comments reviews/11/comments  \
# 133                NaN                 NaN                 NaN
# 134                NaN                 NaN                 NaN
#
#     reviews/12/comments reviews/13/comments reviews/14/comments  \
# 133                 NaN                 NaN                 NaN
# 134                 NaN                 NaN                 NaN
#
#     reviews/15/comments reviews/16/comments reviews/17/comments  \
# 133                 NaN                 NaN                 NaN
# 134                 NaN                 NaN                 NaN
#
#     reviews/18/comments reviews/19/comments
# 133                 NaN                 NaN
# 134                 NaN                 NaN

# %% [markdown]
# #### Using Stanza

# %%
# %%time
df_txt_cols_processed_stanza = parallel_applymap(df_txt_cols, preprocess_txt, worker_count=10, na_action='ignore', nlp_obj=nlp_stanza, lemma=True)
# Out:
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1188 [00:00<?, ?it/s]
#   0%|          | 0/1210 [00:00<?, ?it/s]
#   0%|          | 0/1188 [00:00<?, ?it/s]
#   0%|          | 0/1188 [00:00<?, ?it/s]
# CPU times: user 12min 12s, sys: 1min 23s, total: 13min 35s
# Wall time: 10min 25s

# %%
df_txt_cols_processed_stanza.loc[133:134]
# Out:
#                                 name                     primaryHost/about  \
# 133  casa veraneio praia pernambuco                                    NaN
# 134             alto padrao jardins   engenheiro empresario casado filhos
#
#                                                                                                                                                                                                                                                                                                                                                                                                                              reviews/0/comments  \
# 133  casa perfeita para reunir familia seguranca sossego sao cinco suites oferecem privacidade para todos os hospedes reunimos familiares num ambiente gostoso uma piscina maravilhosa limpa inclusive som ambiente ar condicionado muito eficiente em todos os quartos edna cozinha divinamente mauro deixa dependencias imaculadas ela fez uma lula dore dos deuses super crocantes caipirinha mauro digno um barmanrecomendo sem restricoes
# 134                                                                                                                                                                                                                                                                                                                                            gil apartment fantastic location great apartment spacious cozy gil helpful kind recommend place
#
#                                                                                                                                                                                                                                                                                                                                                                                         reviews/1/comments  \
# 133  mesmo sem conhecer pessoalmente carolina ela sempre foi muito educada simpatica rapida eficiente nas respostas casa superou todas nossas expectativas local enorme acomodou confortavelmente pessoas viajaram comigo os caseiros ficaram todo tempo casa ajudaram algumas tarefas dia dia destaque para feijao da edna churrasco mauro esta meus planos voltar em breve para passar mais alguns dias
# 134                                                                                                                                                                                                                                                                                                                                                                                                    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                             reviews/2/comments  \
# 133  carolina incredible house property beautiful person pictures house pool perfect multigenerational family art lovers multiple lounge game play areas beach blocks stunning beaches visit short drive understand work caseros bit learning curve speak portugues accustomed day figure mauro edna fantastic improve wifi extend entire house highly recommend carolina property hope visit
# 134                                                                                                                                                                                                                                                                                                                                                                                        NaN
#
#     reviews/3/comments reviews/4/comments reviews/5/comments  \
# 133                NaN                NaN                NaN
# 134                NaN                NaN                NaN
#
#     reviews/6/comments reviews/7/comments reviews/8/comments  \
# 133                NaN                NaN                NaN
# 134                NaN                NaN                NaN
#
#     reviews/9/comments reviews/10/comments reviews/11/comments  \
# 133                NaN                 NaN                 NaN
# 134                NaN                 NaN                 NaN
#
#     reviews/12/comments reviews/13/comments reviews/14/comments  \
# 133                 NaN                 NaN                 NaN
# 134                 NaN                 NaN                 NaN
#
#     reviews/15/comments reviews/16/comments reviews/17/comments  \
# 133                 NaN                 NaN                 NaN
# 134                 NaN                 NaN                 NaN
#
#     reviews/18/comments reviews/19/comments
# 133                 NaN                 NaN
# 134                 NaN                 NaN
